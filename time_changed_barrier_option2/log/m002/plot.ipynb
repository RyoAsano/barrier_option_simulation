# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num_of_subdivitions=[1,5,10,15]
abs_err=[1.74091,0.146563,0.0265278,0.0106051]

# %%
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

x=np.arange(0,3.0,0.01)
first_order_line=np.log(abs_err[0])-x
first_and_a_half_order_line=np.log(abs_err[0])-1.5*x
second_order_line=np.log(abs_err[0])-2*x

plt.figure(dpi=150)
plt.plot(x,first_order_line,'--', label=r'$\mathcal{O}\left(N^{-1}\right)$')
plt.plot(x,first_and_a_half_order_line,'--', label=r'$\mathcal{O}\left(N^{-1.5}\right)$')
plt.plot(x,second_order_line,'--', label=r'$\mathcal{O}\left(N^{-2}\right)$')
plt.plot(np.log(num_of_subdivisions), np.log(abs_err), '-bo')
plt.grid(linestyle='--')
plt.ylabel(r'log of absolute error')
plt.xlabel(r'log of number of subdivisions')
plt.legend()
plt.title(r'Absolute error of the time-changed Euler--Maruyama algorithm')
plt.savefig('log_log_plot.png')
plt.show()
