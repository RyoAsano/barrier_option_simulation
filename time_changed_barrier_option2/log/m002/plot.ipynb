# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num_of_subdivitions=[1,5,10,15]
abs_err=[1.74091,0.146563,0.0265278,0.0106051]

# %%
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

x=np.array([1,5,10,15])
first_order_line=abs_err[0]/x
first_and_a_half_order_line=abs_err[0]/(x**1.5)
second_order_line=abs_err[0]/(x*x)

plt.figure(dpi=150)
plt.loglog(x,first_order_line,'--', label=r'$\mathcal{O}\left(N^{-1}\right)$')
plt.loglog(x,first_and_a_half_order_line,'--', label=r'$\mathcal{O}\left(N^{-1.5}\right)$')
plt.loglog(x,second_order_line,'--', label=r'$\mathcal{O}\left(N^{-2}\right)$')
plt.loglog(num_of_subdivisions, abs_err, '-bo')
plt.grid(True, which="both", linestyle='--')
plt.ylabel(r'absolute error')
plt.xlabel(r'number of subdivisions')
plt.legend()
plt.title(r'Absolute error of the time-changed Euler--Maruyama algorithm')
plt.savefig('log_log_plot.png')
plt.show()
